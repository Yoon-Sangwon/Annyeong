# %%
stname = "유니코"; stage=20; stavg=95.869
print(stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다")
print(stname, "학생은 나이가 ", stage, "이고 평균은 ", stavg, "입니다", sep="")
print("%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg))
print("{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg))
print(f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다")
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
v1 = stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다"
v2 = "%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg)
v3 = "{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg)
v4 = f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다"
print(v1)
print(v2)
print(v3)
print(v4)
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
import sys
print(sys.version)

# %%
import os
print(os.getcwd())

# %%
# !jupyter kernelspec list

# %%
# !dir

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
res_header = res.getheaders()
print("[ header 정보 ]----------")
for s in res_header :
    print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# [ header 정보 ]----------
# ('Server', 'NWS')
# ('Date', 'Wed, 24 Mar 2021 08:27:03 GMT')
# ('Content-Type', 'text/html; charset=UTF-8')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Set-Cookie', 'PM_CK_loc=d932d34f90395affcbc5e9308c77b8a41daf9fe2d55303702be1e832711c8263; Expires=Thu, 25 Mar 2021 08:27:03 GMT; Path=/; HttpOnly')
# ('Cache-Control', 'no-cache, no-store, must-revalidate')
# ('Pragma', 'no-cache')
# ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"')
# ('X-Frame-Options', 'DENY')
# ('X-XSS-Protection', '1; mode=block')
# ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains')
# ('Referrer-Policy', 'unsafe-url')

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read())
print(res.read().decode('utf-8'))
# Out:
# <http.client.HTTPResponse object at 0x0000025817E8FB20>
# [ header 정보 ]----------
# ('Date', 'Wed, 24 Mar 2021 08:34:55 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.daum.net/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.aladin.co.kr/home/welcome.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.daum.net/  페이지의 인코딩 정보 : utf-8
# <!DOCTYPE html>
# <html lang="ko" class="">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta property="og:url" content="https://www.daum.net/">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Daum">
# <meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
# <meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">
# <meta name="msapplication-task" content="name=Daum;action-
# ===========================================================
# https://www.aladin.co.kr/home/welcome.aspx  페이지의 인코딩 정보 : utf-8
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" >
# <html>
#   <head>
#       <title id="Title">알라딘</title>
#       <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
# 	  <meta content="Microsoft Visual Studio .NET 7.1" name="GENERATOR">
# 	  <meta content="C#" name="CODE_LANGUAGE">
# 	  <meta content="JavaScript" name="vs_defaultClientScript">
# 	  <meta content="http://schemas.microsoft.com/intellisense/ie5" name="vs_targetSchema">
#       <meta http-equiv="
# ===========================================================

# %%
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# [ URL 문자열 정보 추출 1 ]
# 타입정보 :  <class 'urllib.parse.ParseResult'>
# 도메인정보 :  movie.daum.net
# 패스정보 :  /moviedb/main
# 쿼리정보 :  movieId=93252
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :
# URL 문자열정보 :  https://movie.daum.net/moviedb/main?movieId=93252
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='movie.daum.net', path='/moviedb/main', params='', query='movieId=93252', fragment='')
#
# [ URL 문자열 정보 추출 2 ]
# 도메인정보 :  docs.python.org
# 패스정보 :  /3/library/urllib.parse.html
# 쿼리정보 :
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :  urlparse-result-object
# URL 문자열정보 :  https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='docs.python.org', path='/3/library/urllib.parse.html', params='', query='', fragment='urlparse-result-object')
#
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("c:/Temp/test.jpg")

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
print(bs)

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[ string 속성 ]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[ text 속성 ]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[ contents 속성 ]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
# Out:
# [ string 속성 ]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [ text 속성 ]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [ contents 속성 ]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <class 'bytes'>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] 
    #content=re.sub("신고", '', content)
    content=re.sub("[\n\t]", '', content)    
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 네버엔딩 스토리
# 평점 : 10
# 리뷰글 : 넷플릭스에서 왠걸 하고 봤네요ㅎㅎㅎ어렸을때 봤을땐 분위기가 너무 어두워서 무서웠는데 지금보니 메세지가 강하고 좋은 영화였네요 :) 명작
# -----------------------------------------
# 영화 제목 : 블러드 다이아몬드
# 평점 : 10
# 리뷰글 : 디카프리오 연기 디테일이 살아잇고만
# -----------------------------------------
# 영화 제목 : 조커
# 평점 : 10
# 리뷰글 : Don't forget to smile!
# -----------------------------------------
# 영화 제목 : 웨이 다운
# 평점 : 7
# 리뷰글 : 그대 마음을 뛰게 하는 무언가가 다가온다면 주저말고 도전하고 열정을 쏟아라.
# -----------------------------------------
# 영화 제목 : 강시선생 3 - 영환도사
# 평점 : 7
# 리뷰글 : 오요한 아저씨의 알몸연기가 우습다.
# -----------------------------------------
# 영화 제목 : 고질라 VS. 콩
# 평점 : 4
# 리뷰글 : 너무너무 꿀잼임 꼭보셈
# -----------------------------------------
# 영화 제목 : 고질라 VS. 콩
# 평점 : 8
# 리뷰글 : 솔직히 아쉬운점도 있었던거같아요 제목부터 고질라vs콩인데 정작 싸우는건 별로없는것같이 느껴졌고 좀더 둘이 치고박고 싸우는 장면이 많았다면 정말 명작이었을텐데 너무 인간들 얘기로 집중이 된건 아닌가라는 생각이 드네요 차라리 전작에 등장했던 괴수들이 좀더 많이 나와 고질라와 킹콩과 싸웠다면 더 재밌었을텐데 예를 들어 전작에 죽지않았던 로단도 있을테고....두번 싸운게 끝이라서...그리고 싸운거보면 감독이 고질라팬인건지 고질라를 더 좋아하는건지 모르겟는데 킹콩이 너무 고질라상대로 힘을 못쓴다?라는 느낌을 받았어요 전작부터 계속 둘이 싸울거처럼 둘이 한판붙으면 세상이 종말될듯이 싸울거처럼 떡밥을 엄청 뿌려놨었는데 정작 싸운거보면...아쉽다는 생각밖에는 안드네요 몬스터버스의 마지막작품이라고했는데 그만큼 좀 대형 몬스터들이 더 많이 출현해서 서로 치고박고 싸우는모습들이 많이 그려졌으면 어땠을까하는 아쉬움이 남네요 그렇지만 그래도 둘이 싸운모습을 본건 오락영화로써는 충분히 재밌었다고 봐요
# -----------------------------------------
# 영화 제목 : 극장판 귀멸의 칼날: 무한열차편
# 평점 : 10
# 리뷰글 :
# -----------------------------------------
# 영화 제목 : 잭 스나이더의 저스티스 리그
# 평점 : 9
# 리뷰글 : 이게 참된 영화지
# -----------------------------------------
# 영화 제목 : 잭 스나이더의 저스티스 리그
# 평점 : 10
# 리뷰글 : 문제에 대한 정확한 답.
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        #content=re.sub("신고", '', content)
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 10,고질라 VS. 콩,보는내내지루하지않았어요~
# 10,테넷,진짜이해못하면볼수없다이해하면명작중의명작임
# 1,고질라 VS. 콩,남북합작용가리vs불가사리만들면10점준다
# 10,극장판 귀멸의 칼날: 무한열차편,영화자체는너무좋았음3/27노원롯데시네마오전10시에온사람들이문제지제발영화보러왔으면기본예절좀지키세요님들늦게온사람들은자리에빨리앉고나갈거면빨리나가세요왜잘보고있는사람들자막,화면가려서빡치게합니까개념좀챙깁시다
# 8,고질라 VS. 콩,
# 10,타이타닉,ㅠㅠㅠㅠ이때까지본영화중에제일감동적이고슬어요
# 6,스파이의 아내,"스파이'도'아내'도되지못했다
# 4,최면,토요일오전에영화관사람많았는데상영관에서어떤아저씨랑나만봄..근데그아저씨는보다가중간에나가버리고그큰상영관에서나혼자봄..상영관에서혼자영화본건처음임영화가좀애매하네
# 8,클로버필드 10번지,
# 1,에베레스트,댓글알바멈춰!!!(중뽕영화입니다.보다가심히불편하실수있으니상영하실려면신중을가하셔서보실지말지를선택하시기바랍니다.혹시나...정말혹시나보기는싫으신데내용은궁금하신분들은유튜브에영화유튜버들이영상많이올려났으니보시면될거같습니다.그럼좋은하루되세요.)
# -----------------------------------------------------
# 10,시카리오: 데이 오브 솔다도,의외로재미있고박진감넘치네요
# 10,더 셰프,마지막엔딩너무좋네,조금씩가족이되어가는
# 10,살인자의 기억법,한국에서보기드믄수작이네요.연출이끝내줍니다.스토리,배우들의연기,차가운영상미,강렬한사운드어느것하나부족함이없네요
# 2,백두산,이정도면감독이하제작진직무유기횡령배임수준으로감빵에쳐넣어야지.그돈갖다뭐했냐??
# 10,쥬라기 공원,그래...이게영화지!!!!
# 10,악마를 보았다,최민식연기미쳤다...
# 10,바이 더 씨,영상미가너무좋았던잔잔한영화....졸리너무이쁘고피트너무멋있..ㅠ
# 10,월스트리트: 분노의 복수,황금만능주의의폐해를제대로보여준영화네요.하지만속이다시원하네요.자본주의사회에서는돈이최고가맞긴하지만너무돈을밝히다간제대로망하고말죠.그나저나터미네이터에드워드펄롱오랜만이네요?어디서많이본얼굴이다했더니~~ㅋㅋ마지막결론이어이가없네요~ㅡ_ㅡ;
# 10,고질라 VS. 콩,영화관을찢어버렸다..두괴수의싸움에심금이울렸ㄷr..☆
# 8,지옥행 특급택시,영화재미있네요10점주고싶지만한국어제목지은분의미친센스에-2점드립니다어디가서제목은지으려하지말고그냥그대로번역하시길..
# -----------------------------------------------------
# 10,고질라 VS. 콩,와진짜미치도록재밌음..!!!동생이재밌다고했고두번째로본건데확실히이건영화관에서봐야함..진짜큰화면으로소리가빵빵하게나오는데레전드다.진짜100퍼센트만족하면서봄..진짜이건영화관에서보는걸추천함.진짜보고나왔는데또보고싶음..개존잼
# 3,고질라 VS. 콩,출연배우들찍으면서얼마나힘들었을까?손발이오그라들고극도의유치함을참고대사를뱉어야되니
# 10,잭 스나이더의 저스티스 리그,이것이온전한저스티스리그후속작도잭스나이더바해야됨을명확히보여준다
# 10,고질라 VS. 콩,콩과고질라.이둘의액션만으로도돈값은다한다.개인적으론그이상.
# 10,극장판 귀멸의 칼날: 무한열차편,진짜너무재미있었습니다영화보다가울뻔했습니다진짜최고명장면!!!여러분안보면진짜후회합니다그리고렌고쿠..사랑해요ㅠㅠㅠㅠ(평점좀늦게등록했네요영화봤던날짜:3월20일)
# 7,새해전야,이젠익숙한포맷이지만그래도웃음지으며기분좋게볼수있는영화..사람은사람이치유한다..^&^
# 7,멀리가지마라,금욕때문에소중함을잃어버리는멀리가는작품,연극적연출과독립된공간이며고립된공간에서이뤄지는식상한다툼연출만이아니라야외로의연출이식상함을삭제했다
# 10,극장판 귀멸의 칼날: 무한열차편,그냥잼남어떤사람들은스토리스토리그러는데아주도특한스토리가쉽나요평범한스토리로재미를만들어내면이제는충분합니다
# 4,미션 파서블,너무유치한연기뻔한스토리.배우들이고생해서별2
# 6,톰과 제리,어릴적추억소환성공..톰은여전하고제리는많이착해진듯..^&^
# -----------------------------------------------------
# 1,백두산,뭔얘기를할려는지몰랐는데한가지는확실함.미국을악으로북한과중국을선으로.전형적인좌빨영화.40대가좌빨대깨문이많다더니..두감독얼굴보니역시관상은과학이다..
# 10,극장판 귀멸의 칼날: 무한열차편,넘나감덩입니다...여운이많이남네여
# 3,고질라 VS. 콩,치고박고하는단순한내용일껄누가모르냐.일본배우나올때대충예상되더라.콩하고고질라말고다른괴수는듣보잡이냐?스컬크롤러?날아다니는이상한원시뱀대가리?로단하고메카기도라어따팔아먹었냐?그외잡몬스터는.메카고질라?그딴거누가예상못했을줄아냐원작이일본특촬물인데?재미없더라cg라는조미료로범벅을했을뿐이지.노력이가상해서별1개반준다.
# 8,극장판 귀멸의 칼날: 무한열차편,백종원의프렌차이즈느낌.그래도가게인테리어는정말좋았다.
# 10,잭 스나이더의 저스티스 리그,
# 10,고질라 VS. 콩,도수치료하는킹콩보고피식했지만예상치못한적의등장으로시간가는줄모르고봤습니다.잼있네요ㅎ
# 1,극장판 바이올렛 에버가든,NOJAPAN
# 6,크루아상,그냥별생각없이편하게볼수있는영화
# 8,스파이의 아내,발견.
# 1,디지몬 어드벤처 라스트 에볼루션 : 인연,NOJAPAN
# -----------------------------------------------------
# 2,007 스카이폴,It사회로진입한현시점에서는B급이었던해킹장면들이폐급으로보인다.모든연출들이쌈마이보단싸구려가되었고Ip만남은쭉정이킹스맨보다몇단계는뒤떨어져전혀자극적이지않고내내지루하다.
# 10,잭 스나이더의 저스티스 리그,핡
# 1,트랜스포머,
# 10,고질라 VS. 콩,흥미진진.박진감넘쳤네요~너무잼나게봤어요^^
# 6,음양사 : 청아집,디즈니+센과치히로+닥터스트레인지등각종장면과연출을연상케하나재미로만따지면재미나게볼수있는작품
# 5,라야와 마지막 드래곤,급전개만빼면다좋았음.
# 10,고질라 VS. 콩,이거뭐이래잼있는거야~!
# 10,극장판 귀멸의 칼날: 무한열차편,토착왜구지껄이는대깨문들이거잘나가는거보고얼마나뚜껑열릴까...ㅋㅋㅋ그것만생각해도속이뻥뚫리는것같다.ㅋㅋㅋ글고유튜브에서나름평론가랍시고이리저리지맘대로평론하고난뒤에이거개봉해도대박못친다고했던그놈...니가뭘안다고씨부리냐?솔직히나도귀칼tv판다보고이건아직못봤지만...일본현지에서부터난리났을때,이미알고있었다.여기와도대박칠거라는걸...뭐,조선이지배당하고있던시대라서NG?주인공귀걸이에걸린게전범기?x랄한다...ㅋㅋㅋ누가그런거따지면서영화보냐??니들대깨문들이나그러지.그리고탄지로귀걸이는전범기가아니거든?꽃문양이다.물론욱일기모양을본뜬건맞지만,욱일기는원래민간에서풍요의신같은상징적인의미로태양을본뜬이미지를사용하고있던걸당시군부가지들마음대로군기로쓴거다.그리고피지배국이됐던게그리수치스러우면왜지배를당했는지를잘알아보고무력하고부패했던조선시대의윗대가리들을탓해라,x신들아ㅋㅋㅋ아무튼국뽕x끼들보면토가절로나온다니까...
# 8,고질라 VS. 콩,전작고질라에서손절하려했으나화려하게부활했다
# 10,메가 블리자드,
# -----------------------------------------------------
# 7,시크릿,대박반전?이상하다했는데이유가있었네
# 10,고질라 VS. 콩,진짜너무재밌음극장가서한번꼭보시는거추천드림액션장난아님ㅎㄷㄷ...
# 9,국제수사,B급배우들이출연하지만탄탄한스토리와탄탄한연기력에최상급영상미...최고라고할수있어요근데여기평점알바들뭐하는짓인가요?
# 10,다빈치 코드,심심해서이제서야봤는데재밋었음
# 10,아쿠아맨,
# 10,고질라 VS. 콩,어벤져스보다더재미있고감동끝판왕^^스케일최고!
# 10,고질라 VS. 콩,진짜겁나잼잇음이렇게싸워야잼잇지
# 10,고질라 VS. 콩,어제는적오늘은친구이영화보고라이벌도동료가될수있다는것을느꼈다
# 10,잭 스나이더의 저스티스 리그,
# 9,라야와 마지막 드래곤,초등생보기에재미엤고감동있어요..
# -----------------------------------------------------
# 10,고질라 VS. 콩,오랜만에극장가서영화다운영화를보고왔네요.볼까말까고민하시는분들,꼭보고오시는걸추천드립니다.괴수들의싸움,액션연출,OST,다좋습니다.
# 10,몰리스 게임,.
# 1,고질라 VS. 콩,고질라콩때매수천만명은뒤졌을듯.ㅋ
# 9,고질라 VS. 콩,생각보다탄탄한스토리에주목하라
# 10,시동,마동석개그가너무웃겨서몇번이고본영화ㅎㅎ
# 10,태양은 없다,비트와태양은없다는내인생최고멋진영화다이보다멋진영화20년이지나도다시또다시보는영화는없다평생소장영화
# 4,반딧불이 딘딘과 용감한 곤충 탐험대,아이랑극장가려고보긴했는데...다른옵션이있다면다른걸추천드립니다
# 10,시간을 달리는 소녀,
# 4,나이스 걸 라이크 유,왜항상로맨틱드라마는이런식인지ㅉㅉㅉ
# 10,고질라 VS. 콩,빠른전개.지루해진다싶으면나오는통쾌한액션들,전혀어색하지않은고질라와콩그래픽작업거기에소소한감동까지...돈주고볼만하다
# -----------------------------------------------------
# 4,미나리,뭘기대하지말고보세요영화속에진짜진짜아~무것도없어요그냥본인들까리싸우다탁끝나요진짜뜬금없이탁끝나서끝난지도몰랐어요허나이상하게영화가몰입이되서의외로돈이아까운생각이안들었습니다
# 10,고질라 VS. 콩,영상미가좋네요강추합니당
# 10,고질라 VS. 콩,어...진짜재미있어요레알로다때려부시고너무너무재미있게싸우고뭐쓸데없는인간들없애고..진짜몰입감이짱이였습니다다만영화초반에진짜소리가커서...제가MX관이여서그러는지모르지만초반에귀조심하세요그거빼면진짜재미있었습니다
# 10,잭 스나이더의 저스티스 리그,아예다른영화인줄.너무재밌다
# 9,고질라 VS. 콩,최고!감동!TV로보면재미없을것같다!
# 7,고질라 VS. 콩,거대괴수물에서볼수있는세팅은모두선보인느낌.구경하기쉽잖은박력을체험하시길.
# 10,고질라 VS. 콩,코로나지만분명극장에서필히봐야되는영화.정말재밌음
# 1,반딧불이 딘딘과 용감한 곤충 탐험대,아이들이보기에최악의영화,계속긴장,포악,마음을피폐해지게만들수있음.중국스러움
# 10,고질라 VS. 콩,극장에서꼭보십쇼ㅋㅋㅋ
# 2,백두산,낙하하는데소총을다리에안메고뛰는게말이되냐ㅋㅋㅋ감독미필인가
# -----------------------------------------------------
# 8,고질라 VS. 콩,고질라와콩의생김새로편견을가지고있었는데,감동ㅠㅠ생긴거로판단하면안되겠다.고질라콩알러뷰!♡
# 8,고질라 VS. 콩,
# 10,잭 스나이더의 저스티스 리그,와진짜,이거극장재개봉해야한다
# 10,카센타,스토리가탄탄하고재밋음
# 9,겨울왕국 2,
# 8,미옥,쎄다..살인,잔인폭력이너무많음.사랑?하는사람을그렇게난도질해놓나..김혜수♡♡이선균♡♡
# 10,타이타닉,
# 10,쿵푸 허슬,병맛같은데병맛같지않는영화이런게영화다
# 10,소울,인생영화믿고보는디즈니ㅜㅜ
# 10,그날, 바다,
# -----------------------------------------------------
# 10,티벳에서의 7년,티베트의독립그리고중국소수민족은절대중국이아닙니다라는메시지를심어준영화
# 10,고질라 VS. 콩,내가여태까지본괴수물중에제일재밌었던거같아요
# 10,고질라 VS. 콩,이정도면충분함어설픈인간개입도많이없는편이고
# 10,고질라 VS. 콩,진짜로가슴이웅장해짐찐괴수대전
# 10,검객,그냥저냥볼려고봤는데....오잘만들었네..재미있게잘봤습니다.
# 10,해리 포터와 불사조 기사단,해리포터시리즈다봤는데너무재밌어용헤르미온느넘이쁨
# 8,고질라 VS. 콩,액션은최고였다..다소유치했다..
# 8,사랑이 지나간 자리,첫장면1분부터모든영화가마킹하면특별할지도
# 1,최면,코로나때문에너무닫혀있는것같은내용재미는없어었어요
# 1,천군,중국인박계옥.동북공정동조기업SBS재허가반대!
# -----------------------------------------------------
# 4,고질라 VS. 콩,기대하고가면재미없고싸우는거아니면지루함
# 4,고질라 VS. 콩,액션씬말고는그닥...
# 10,바르게 살자,몇번을봐도ㅋㅋ매년한번씩은보는영화
# 1,다이빙벨,와대깨문들다이빙벨에서일어났던일들알도평가해봐라
# 10,극장판 귀멸의 칼날: 무한열차편,눈물질질엄마랑같이봤어요,,
# 2,개 같은 것들,OO이형은나가있으라니까왜영화찍고그래?
# 8,고질라 VS. 콩,기대를너무햇나봅니다
# 10,고질라 VS. 콩,너무재밌게봤습니다!!
# 10,고질라 VS. 콩,괴수들의양대산맥이격돌합니다!더바랄게있나요!
# 8,어메이징 그레이스,미국이노예제도폐지한줄알았는데영국이먼저한거였네
# -----------------------------------------------------
# 8,리턴 투 센더,오..처단한거군요...아빠개도미리연습해본거고..다계획이있었구나...벌은받아야하지만무서버..그런데그범인은다회개한고아니죠??철물점서그동전계산하는폼보면...고쳐쓰는게아니라고...
# 10,고질라 VS. 콩,스토리이런거다떠나서눈이즐거웠다..간만에영화다운영화를본듯한기분...
# 10,극장판 귀멸의 칼날: 무한열차편,역시유포다...작화진짜좋았음
# 10,톰과 제리,정말재밌어요!강추!!
# 1,옥자,개노잼..봉준호는거품
# 10,고질라 VS. 콩,크롱과코코몽은사이좋은친구랍니다.그럼친구들다음에만나요~!
# 10,극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!,그러면엄마는누가지켜줘.나도아빠구할꺼야
# 10,고질라 VS. 콩,걍미쳤습니다웬만한마블영화보다재밌는듯
# 8,미나리,잔잔히스며드는모정의강한힘줄
# 10,승리호,어우야나름재밌겠봤습니다~우주,사이버펑크느낌
# -----------------------------------------------------
# 9,세상의 모든 계절,어떠한인생을살것인가에대한원인은그사람안에존재한다.불행=메리,행복=제리메리는본인의욕망에충실한삶을사는사람이다.(ex.성급한혹은충동적차량구매및한결같은남성선택의기준이외모)제리는사람의인성과그사람의생각을존중하는사람.(ex.아들의여자친구케이티를대하는자세및영화속모든등장인물들을대하는자세와거기에빌런급인아들추파던지기전메리대하는자세)더중요한것은2010년영화인데외부적으로보여지는것에대해충실한삶을사는요즘(EX.SNS)이영화는정말로행복한삶이무엇인지근본적인결과를보여준다고생각한다.겉보기에좋아보이니까그곳에기준을두고쫓아가는삶(욕망에충실한삶)이과연행복한삶일까?남들에게자랑하는삶을사는사람보다본인의행복을명확히알고거기에충실한사람들이행복하게잘살아요.
# 10,고질라 VS. 콩,최고로재밌네요코로나아니면관객이많을테데
# 10,월터의 상상은 현실이 된다,마지막장면은내가본영화중최고!
# 9,마진 콜: 24시간, 조작된 진실,그저참담한심정을느끼며
# 10,태백산맥,이념의갈등이지금까지되는가운데이영화는꼭봐야하는명작입니다.이념의갈등은땅에서부터입니다.우리가왜이념으로갈등하는지알아야하고그시작이어디서부터였는지여실히알려준영화.역시임권택감독님.역시조정래선생님.
# 8,최면,일행땜에보게됐는데공포영화를잘못봐서그런지너무무서웠어요ㅠㅠㅠ영화는생각보단괜찮았음
# 7,포제서,좀더잔인하고어하다철학을넣기에는너무피가튀겼다붉은색만부각됨
# 8,미나리,아주흥미진진하진않으나의미있는스토리와잔잔한영상이좋았습니다.
# 10,1917,영화를보는내내행복했어요~
# 10,미션 파서블,오락영화로이정도면상당한수작인데도대체우리나라의오락영화수준은어디까지길래평점이이리도낮은지?
# -----------------------------------------------------
# 6,고질라 VS. 콩,중국자본들어갔는지계속볼때마다퍼시픽리그생각나더니메가고질라라니보기만해도끔찍하네요몬스터유니버스에괴수로봇이왠말입니까재미도감동도없네요
# 10,고질라 VS. 콩,때리고부수고~~이런시원함이필요했던요즘....참속뻥뚤리는영화입니다~!
# 10,극장판 귀멸의 칼날: 무한열차편,가슴이웅장해지는영화
# 10,잭 스나이더의 저스티스 리그,와..4시간이안지루했다.이거지!그전에저스티스리그보고돈아까웠는데대박이네요.4시간으로세계관이부족하다생각들긴하지만투자한돈이안아깝네요.다운받아볼까하다가제대로보고싶어서btv소장결제하고두번째보고있네요.잘봤습니다.
# 9,고질라 VS. 콩,스토리가아쉽긴하지만연출은지렸습니다...
# 10,담보,보는내내울다가웃다가...가슴먹먹해지고울컥해지네요이세상모든부모님들존경하고사랑합니다
# 10,극장판 귀멸의 칼날: 무한열차편,역대급애니메이션말을아직도정리를못하겠음
# 10,고질라 VS. 콩,아이맥스로보세요.혼자가니까주말도예매되네요.
# 10,고질라 VS. 콩,몬스터버스최고의시리즈가아닐까
# 9,고질라 VS. 콩,항공모함전투씬에서레알웅장함.중반부에서좀긴장감이떨어졌는데후반부에둘이서제대로목숨걸고(?)싸우는데진짜대박.갠적으로마지막전투보다후반부전투씬이훨씬더나은듯.그래도난고질라가더좋다
# -----------------------------------------------------
# 7,고질라 VS. 콩,고질라VS콩은개연성이처음부터끝까지없다.하나도말이안됀다.그러나제작진들은영화속에서하고싶은걸다한눈치이다.그래,개연성이고그런게뭐가필요해.다뿌시면장떙이지!
# 10,아수라도,좋은영화잘보고갑니다:)
# 10,극장판 귀멸의 칼날: 무한열차편,인생영화개명작진짜개띵작중추신경부터짜릿해짐진짜개웅장함안본사람없어야됨
# 10,극장판 귀멸의 칼날: 무한열차편,렌코쿠...ㅠ내음속영원히
# 10,마리오네트,망작한국영화에는평점퍼주면서이런명작에평점준꼬라지봐라…그냥지들이이해못하면다재미없다고함ㅋㅋ이거베를린영화제상영작에도선정되서세계적으로나름인정받은수작인데우리나라에선왜이리까이는거임?솔직히8~9점대는되는영화임.
# 10,고질라 VS. 콩,개꿀잼막판에감동ㅠㅠ
# 9,극장판 귀멸의 칼날: 무한열차편,연출이훌륭합니다재밌게봤어요
# 10,어디갔어, 버나뎃,나는천재였던적도없고유명인인적도없는데버나뎃에너무공감이돼서자꾸만눈물이났다
# 4,최면,1점주려다가연출에나름신경쓴거같아서조금더줌.볼거는가끔나오는갑툭튀와조현밖에없다.
# 6,라야와 마지막 드래곤,이게9.45...?작품성도그저그렇고딱가볍기그지없는영화.개인적으로겨울왕국2보단재밌었지만주먹왕랄프보다는훨씬노잼,소울이랑은비교자체가안되는영화
# -----------------------------------------------------
# 10,극장판 귀멸의 칼날: 무한열차편,
# 7,퍼스트 리폼드,사랑이었을까?피난처였을까?
# 10,이 안에 외계인이 있다,결국조병규씨제외하고전부다외계인이었다는말인가??마치,한편의연극을보는듯하였다.
# 1,완벽한 타인,평점이너무높네요6.5점정도가적당함.
# 10,토이 스토리 3,Solongpartner...
# 10,더 박스,음악이계속맴도네요...
# 10,고질라 VS. 콩,재밌었어요박진감넘치는격투씬쵝오!
# 10,고질라 VS. 콩,재미있게잘봤어요잘만들었네요~
# 10,극장판 귀멸의 칼날: 무한열차편,코코로오모야세...3번봐도질리지않는갓쥬로..빛쥬로...말해모해..
# 10,극장판 귀멸의 칼날: 무한열차편,극장에서2번봤어요전VOD나오면살꺼에요개존잼ㅠㅠ영화보세요두번보세요ㅠㅠ
# -----------------------------------------------------
# 10,고질라 VS. 콩,실감나고재밌었어요!!오랜만에화끈한영화잘보고갑니다ㅋㅋㅋ
# 10,라야와 마지막 드래곤,2주연속극장에서보고있어요ㅡ아이들과함께오늘은조조영화로보았어요
# 10,미나리,채소농사가건강에좋다는것,미나리의생명력이매우강하다는걸잘보여준영화라고생각합니다.
# 10,싱글라이더,모든걸상실하고바닥까지텅빈..처연하고도아픈눈빛이계속떠오른다..이병헌의감정연기는어느누구도흉내내지못할것이다..
# 10,고질라 VS. 콩,진짜괴수영화중원탑꼭보는걸추천할게요!!
# 10,고질라 VS. 콩,그냥말이필요없습니다그저갓영화
# 10,고질라 VS. 콩,레전드시리즈의레전드피날레
# 10,연인,베드씬은기억에서사라졌고알수없는묘한감정만남았다
# 10,고질라 VS. 콩,지루한부분없이시간잘가네요ㅎㅎ다음편이나오면좋겠네요ㅎ
# 10,고질라 VS. 콩,2020년부터지금까지개봉한영화들중제일재밌었던거같아요ㅠㅠ진짜최고입니다무조건보세요
# -----------------------------------------------------
# 10,아수라도,악질좌익한겨례21자회사비평가가악담을남긴영화이니,분명훌륭한영화임에틀림없다.반드시보리라.
# 10,고질라 VS. 콩,어제의적은오늘의동료다
# 1,고질라 VS. 콩,진짜급도나누기싫은영화입니다.콩한테왠초능력ㅋㅋ도끼ㅋㅋㅋ..전설의전사괴수?ㅠㅋㅋ마블도아닌데..괴수한테이상한도끼쥐어주고..당연히힘으로해야하는거아닌지..진짜유치하고진짜보는내내너무졸렸고지루하고이렇게재미없는영화처음봤습니다.그리고무기없으면콩고질라한테진거라고말하는거같음미국위는일본인걸말하고싶은영화ㅋㅋㅋ
# 10,반지의 제왕: 왕의 귀환,아이맥스재개봉뉴스만보고덜컥가서봤지만우리지역은아이맥스관이없었고..무삭제판이아니어서아쉬웠다.ㅜ그래도여전히명작.
# 8,고질라 VS. 콩,정말잼있게봤습니다~~^^
# 10,소울,
# 8,고질라 VS. 콩,영화초반콩(구니스)영화중반콩(왕좌의게임)영화후반콩(퍼시픽림)
# 9,스파이의 아내,개인적인안락과이기적애국심을버린"별난남자"를바라보는시선들..오랜만에묵직한전쟁영화가나왔다.아오이유우는그동안사상이변했나?
# 10,좋아해줘,솔직담백한느낌의영화네요무척좋습니다~!!!!
# 10,바람이 분다,일본의군국주의비판과엔지니어들의안타까운인생이담긴명작.
# -----------------------------------------------------
# 10,고질라 VS. 콩,좋아요아이가재미있다네요추천!!!
# 10,고질라 VS. 콩,아이맥스로볼걸그랬어요ㅠㅠ액션이넘나화려함
# 10,고질라 VS. 콩,CG가돋보이는쾌감넘치는액션!!!
# 9,미나리,"쓸모가없으면버려지는거야,그러니까우리는꼭쓸모가있어야되는거야."낯선미국땅에서쓸모가있어지기위해치열하게발버둥치는제이콥.그러나,역설적으로최후에살아남은것은오히려방치하다시피내버려둔미나리다.미나리는그렇게어디서든잘자란다.
# 7,고질라 VS. 콩,지루해서졸림.스토리로보는게아니지만ㅋㅋㅋ돈아까움.
# 10,극장판 귀멸의 칼날: 무한열차편,우와이건말로표현하기어려울정도로너무잼있습니다저도40대고아들과같이봤는데애니보면서눈물글썽거리는거처음이었습니다수많은애니를봤지만스토리를비롯액션하나빠지는거없네여
# 10,고질라 VS. 콩,맨오브스틸고질라콩버전임
# 8,강시선생 2,꼬마강시가귀엽다.무섭지않은코믹강시.
# 4,고질라 VS. 콩,철저한애들용.개연성없는건둘째치고연출력이떨어지니연기력들도떨어져보임.나름sf마니아인데보다가나가고싶었던적이적어도세번있었음.홍콩씬은퍼시픽림1이생각나지만액션성에서비교가안됨.고질라쪽흑인과여자애일행은솔직히왜나온지모를정도로존재감없음.줄거리개연성은지적할곳이한두군데가아니라못적겠음..
# 10,고질라 VS. 콩,너무재밌었습니다.ㅋ
# -----------------------------------------------------
# 10,미션 파서블,영화극한직업이후이정도로웃긴영화는없었다ㅎㅎ여기안웃기네머네하는개소리는신경쓰지마시고꼭보시길코로나아니면최소500만정도영화는될듯합니다
# 10,네버엔딩 스토리,넷플릭스에서왠걸하고봤네요ㅎㅎㅎ어렸을때봤을땐분위기가너무어두워서무서웠는데지금보니메세지가강하고좋은영화였네요:)명작
# 10,블러드 다이아몬드,디카프리오연기디테일이살아잇고만
# 10,조커,Don'tforgettosmile!
# 7,웨이 다운,그대마음을뛰게하는무언가가다가온다면주저말고도전하고열정을쏟아라.
# 7,강시선생 3 - 영환도사,오요한아저씨의알몸연기가우습다.
# 4,고질라 VS. 콩,너무너무꿀잼임꼭보셈
# 8,고질라 VS. 콩,솔직히아쉬운점도있었던거같아요제목부터고질라vs콩인데정작싸우는건별로없는것같이느껴졌고좀더둘이치고박고싸우는장면이많았다면정말명작이었을텐데너무인간들얘기로집중이된건아닌가라는생각이드네요차라리전작에등장했던괴수들이좀더많이나와고질라와킹콩과싸웠다면더재밌었을텐데예를들어전작에죽지않았던로단도있을테고....두번싸운게끝이라서...그리고싸운거보면감독이고질라팬인건지고질라를더좋아하는건지모르겟는데킹콩이너무고질라상대로힘을못쓴다?라는느낌을받았어요전작부터계속둘이싸울거처럼둘이한판붙으면세상이종말될듯이싸울거처럼떡밥을엄청뿌려놨었는데정작싸운거보면...아쉽다는생각밖에는안드네요몬스터버스의마지막작품이라고했는데그만큼좀대형몬스터들이더많이출현해서서로치고박고싸우는모습들이많이그려졌으면어땠을까하는아쉬움이남네요그렇지만그래도둘이싸운모습을본건오락영화로써는충분히재밌었다고봐요
# 10,극장판 귀멸의 칼날: 무한열차편,
# 9,잭 스나이더의 저스티스 리그,이게참된영화지
# -----------------------------------------------------
# 10,잭 스나이더의 저스티스 리그,문제에대한정확한답.
# 10,더 박스,
# 9,강시선생 - 일미도인,우습고무섭다.지금봐도여전히재밌다.
# 10,고질라 VS. 콩,역대최강비주얼...인조고질라목따고포효..압권
# 10,고질라 VS. 콩,고질라VS콩은꼭영화관가서보시길강력추천해요!!!괴수들의압도적인스케일과화려한CG가어울려져지금까지봤던몬스터유니버스영화중가장재밌었어요고질라VS콩두괴수가싸우는부분은눈뗄시간이없을정도로박진감넘치고재밌었어요다만아쉬운점이하나있다면고질라VS콩이몬스터유니버스의마지막작품이라는거에요ㅠㅠ이영화의흥행성적이좋아져서앞으로도계속콩과고질라의이후의이야기와다양한괴수들의이야기도볼수있었으면좋겠어요ㅎㅎ
# 10,잭 스나이더의 저스티스 리그,진짜후속작안나오면화낼거임
# 10,고질라 VS. 콩,이건별100개임아쉽네5개밖에없어서
# 10,소울,애니메이션으로뉴욕배경만으로도굳굳!!ㅎㅎ아여행가고싶네요
# 10,잭 스나이더의 저스티스 리그,마블엔드게임이후제일재밌었다이게디씨라면난앞으로디씨를보겠음
# 10,극장판 귀멸의 칼날: 무한열차편,귀멸의칼날관심도없다가넷플릭스로시즌1보고영화관달려가서봤네요.진짜강추입니다.내려가기전에꼭영화관에서보세요.오열하고나왔어요..애니가이렇게연출을잘하는구나하고느꼈습니다.스토리도감동이에요.
# -----------------------------------------------------
# 10,극장판 귀멸의 칼날: 무한열차편,아들둘이신나게보고스트레스확풀어버린영화였습니다!환상적인액션씬이었습니다!
# 10,마리오네트,어떤시선과가치관으로세상을바라보느냐에따라우리의인생이달라진다는메시지를던져줬다.엔딩에서메리언이매니에게건넨명대사들과크래딧이올라가기직전그녀의마지막눈빛은충격과감동을넘어거대한전율까지선사했다.영화의엔딩을다시보면가슴이웅장해진다.요즘보기힘든명작반전영화.내인생작중하나!
# 10,뮤즈,보고싶은데하는곳이없네요ㅠㅠ
# 8,명탐정 코난:전율의 악보,음치인데절대음감인게말이안되지만...재미는있다
# 2,Da 5 블러드,이런쓰레기영화에별점을남기기도더러운영화흑인인권과유머를합치려했던것같은데결국엔그인권의흑인들도동양에대한인종차별주의자며감독은모든유색인종을쓰레기로생각하는것같음그리고베트남침략에대한미안함이나반성은1도없고눈만버렸음
# 10,극장판 귀멸의 칼날: 무한열차편,마음을불태워라!렌고쿠상ㅠㅠ
# 4,클로젯,분명짬뽕레시피였는데만들고보니그냥짬ㅠ
# 8,메멘토,역순의흐름이신선했지만좀지루함..그저그랬음..
# 5,호랑이보다 무서운 겨울손님,뭐지?잘나가다가호랑이탈은좀...
# 6,극장판 도라에몽 진구의 아프리카 모험 : 베코와 5인의 탐험대,나쁘지는않았지만퉁퉁이를이번극장판에서부각을시키려고한거같은데부각을시키려면제대로시키지어중간하게해놓았네
# -----------------------------------------------------
# 6,고질라 VS. 콩,액션이나비쥬얼은두말할필요없이화려합니다.하지만스토리가지루하고드라마틱함이없습니다.또한,도시하나를괴멸시킬듯한괴수들의싸움인데편집도너무빠르고사운드가부족해서웅장함이나타격감이크게느껴지지않는게많이아쉽습니다.
# 6,극장판 도라에몽: 진구의 우주영웅기~스페이스 히어로즈~,도라에몽극장판은항상뒷부분이엉성하는데이건괜찮다
# 10,최면,영화나름재미있는데재미있게잘봤음
# 10,날아라 허동구,
# 10,허삼관,기대안하고봤는데너무재밋고계속울었네요
# 10,이별의 아침에 약속의 꽃을 장식하자,그냥...볼때마다울어요(슬퍼서ㄴㄴㅈㄴ감동적임)
# 9,고질라 VS. 콩,스토리가약간산으로가지만,이런영화는액션을즐기려고보는것이고이점에선대성공
# 6,부라더,애매하구만.그리재미있지않은데끝까지는봄.
# 10,박열,영화관에서보지못한것이많이아쉽습니다.감사합니다.
# 10,극장판 귀멸의 칼날: 무한열차편,마음을불태워보료땽>ㅁ<
# -----------------------------------------------------
# 10,반지의 제왕: 반지 원정대,인생영화등극3시간48분짜리인데도몰입감이유지되었다.
# 9,고질라 VS. 콩,콩1편을봤었기때문에후속작이란이유만으로그냥보러간건데콩1보다훨재밌었네요ㅎㅎ이번엔그야말로괴수에집중된영화라서머리쓸꺼없이스트레스팍팍풀리는시원하고화려한액션과사운드ㅋㅋ눈으로즐기는스타일의영화.그런면에서정말잘만든듯...이거볼꺼면꼭영화관에서보는걸추천...
# 10,소울,Ifuloved‘abouttime,’umustwatchthisaswell.
# 9,라야와 마지막 드래곤,용서가아닌믿음을말해서좋았다
# 10,김종욱 찾기,영화관에서보고교통사고나서입원해서야다시본영화..몸은몰라도머음까지힐링되네요!다시봐도띵작입니다~이제훈배우,오나라배우도반갑고너무좋네요
# 10,공조,
# 10,공조,
# 10,파이터,진심이라는뚝심으로밀고가는묵직함.좋다.
# 10,고질라 VS. 콩,완전몰입하면서보느냐시간가는줄몰랐어요넘나재미있게잘봤어요~!^^
# 8,고질라 VS. 콩,재밌네요꼭보시길바랍니다
# -----------------------------------------------------
# 2,우상,말도잘들리지않고끝난후엔다시내용이해를위해서서너번은봐야할듯
# 10,잭 스나이더의 저스티스 리그,조스웨던은반성해라....
# 6,아이,이아이만큼은혼자내버려두지않겠다는강한의지.
# 1,썬키스 패밀리,일점도아깝다..이게영화임..?
# 4,미션 파서블,가능한한많이웃기기(시도).
# 10,프라미싱 영 우먼,불편하다고모른척하고방치하고묻어둔다면계속반복할거야.그리고세상에남일은없어
# 8,썬키스 패밀리,연예인은화장빨이라는걸박휘순배우님보고배웠습니다
# 10,고질라 VS. 콩,액션씬은역대고질라시리즈중최고!!
# 4,명탐정 코난: 감청의 권,원래코난영화들은다좋아하는데이건좀많이별로였음,,더빙인데도등장인물이름들다일본어로유지됐고코난은왜뜬금없이까매졌는지모르겠음그거외로내가미국살아서그런건진모르겠는데영어발음진짜듣기너무불편함반은들리지도않는발음임개웃긴게ㅋㅋ중간에“thereheis”이러는데“dirtyass”로들림ㅋㅋㅋ그리고뭔싱가포르의인구반이다일본어하는개연성버린설정개연성얘기하니까또생각난건데날아오는축구공을주먹으로친애가더미친건지몇십킬로미터멀리서부터축구공날린코난이미친건지
# 10,고질라 VS. 콩,기대이상으로재밌네요
# -----------------------------------------------------
# 4,코마,영상이확실히볼만은했지만짧게나오고사진만봐도될듯한영화네요
# 9,소울,보는내내불편한행복감을마주한영화였다.재밌음
# 1,반도,부산행2라고홍보하길래잔뜩기대하게만들어서봤더니이게뭐야...내돈물어내!!!!
# 5,고질라 VS. 콩,설정이OO같다고질라랑호각으로싸우는콩이쇠사슬을못끊어잡혀있고고질라는스치기만해도군함이폭발한다
# 9,싱글라이더,이병헌연기잘함...반전도있고왜흥행을못했지?
# 10,좋은 놈, 나쁜 놈, 이상한 놈,
# 1,#살아있다,영화때문에평점써보기는또처음이네;;어쨋든보고난후결론본지는1년이더지났지만느낀점은박신혜,유아인두분의열연이보기좋았습니다.어떻게든영화를살리고자하셨지만무리셨구요..이영화덕에박신혜에게관심이생겨드라마를몇편챙겨봤다는게끝....좀비영화치고이렇게재미없는영화는처음봄....
# 8,초미의 관심사,귀여운영화네요.매순간화가나있는얼굴이면될치타님의연기였지만조금더발전이있기를기원.조민수님볼수있어서좋았어요.
# 10,좋아해줘,구탱이형이나오시는데지금도살아계실것만같은느낌이강하게듭니다영화에서나마구탱이형을뵈니좋네요ㅠㅠ
# 10,도그빌,말레나와비슷하지만더노골적이고철학적인영화.썩다조지는결말아니였으면화병걸릴뻔
# -----------------------------------------------------
# 1,천군,별점테러하는거우리나라사람들이예민하고과민반응한다고그러는데,입장을바꿔서미국에다링컨이밀수꾼이었다는드라마만들고폴란드에다퀴리부인이밀수꾼이었다는영화만들고하면그나라사람들이잘도가만히있겠어요.이영화유튜브에돌아다니는리뷰영상같은거알고리즘으로떠서봤을때부터진짜저질스럽고천박한느낌이었는데아니나다를까박계옥이었군요.그건그렇고왜모든역사드라마영화에조선족연변사투리를넣는거에요?무슨평양황해도같이연변이랑상관도없는사람들이연변사투리를쓰고있어정말!
# 10,캣츠,난나름재밌었음노래좋고여주고양이이쁨ㅋ
# 10,벤자민 버튼의 시간은 거꾸로 간다,20대에볼때와지금30대에볼때또다르구나.40대에도다르게와닿겠지.명작.
# 2,패닉 룸,총든강도2명이발광하는여자하나제압못하고문을잠그려고하는연출에실소가...
# 10,말레나,도그빌같이마을사람들에게대한복수로멸망엔딩이였으면카타르시스가있었겠지만조금아쉽다.
# 10,라야와 마지막 드래곤,진짜겁나재밌고겨울왕국보다재밌는듯정말스토리짱이고태어나서이렇게재밌는영화처음봄
# 2,그날의 분위기,차라리이게기차여행PPL이라면제작의의도를이해할듯..
# 10,소울,헐나도재즈하고있었네
# 6,고질라 VS. 콩,과한설정이나개연성은전작에비해나아지지못함.다만눈은즐거움.그래눈호강하려고간거니까돈아깝진않았다.
# 10,5일의 마중,장이모와공리는작품성+흥행이죠.붉은수수밭부터두분이만든건다봤습니다..최고의조합..중국의아픈부분을잘드러내며아주중국적인영화를잘만드시는두분..장수하시길..
# -----------------------------------------------------
# 6,여자라는 이름으로,성별싸움이없는시기에나왔으면어땟을까싶은영화
# 10,극장판 귀멸의 칼날: 무한열차편,한동안후유증에헤어나오지못하고있음아카자노래가가만히있어도들릴정도두웅-따라란??쨔잔-
# 7,아수라도,그나마봐줄만한게연기인데연기가부족한부분도보이기도했고연출도미흡한부분도있었지만가장아쉬운건소리였다저예산영화맞다는걸확인했지만더위로올라갈만한작품이되려면소리가급선무같다
# 10,고질라 VS. 콩,결국이루어질수없는영장류와파충류의유쾌하고감동적인사랑이야기.
# 4,배심원들,배심원제가성공하려면그들의자유로운토의가필수인데.판사가마구개입하네?대체뭔의도인지..그리고한국영화는판사.또는의사가우르르몰려다니는장면이이리많냐?혼자다니면권위안서서?
# 2,고질라 VS. 콩,킹오몬에서부터도스토리,전개보다액션씬만보겠다고생각하고봤는데고질라가콩의도끼에힘을불어넣어메카고질라를무찌른다?이건진짜선넘은게아닌가싶다;
# 1,천군,시간낭비쓰레기영화..
# 10,아수라도,좋은글이많아서보았다가클레멘타임인걸알았습니다.문서연님만은예쁩니다.모두재미있게보세요^^;
# 8,소울,
# 2,미션 파서블,10점준잡것들아이디클릭해서평점기록보셈.알바딱티가나쥬~이딴것도영화라고ㅉㅉㅉ
# -----------------------------------------------------
# 8,잭 스나이더의 저스티스 리그,이런영화가어떻게2017년도에는그렇게나올수있었던건가...각캐릭터다살려놨고스토리개연성있구...배우연기도받쳐주고...2017년도에어떻게말아먹을수가있었던거지???
# 6,마담 싸이코,결국은에펠탑에갇혔네.
# 10,리틀 포레스트,이영화가나의작은숲이되었다.
# 10,고질라 VS. 콩,몬스터버스영화중가장최고인영화전작처럼괴수파트에서인간파트로넘어가는부분이없는완벽한괴수영화
# 1,얼굴없는 보스 : 못다한 이야기 감독판,자다깨서봤는데뭔가있겠지하고끝까지본나에게벌을주고싶다..
# 10,라이프 오브 파이,이영화는두번보길추천합니다.코로나이후일부종교에대한인식이달라진지금다시보니느낌자체가변합니다.명작.
# 10,부활,살아가면서최고의가치가무엇인지를깨닫게해주는영화입니다.모두가이태석신부처럼헌신하며살수는없지만조금덜부끄럽게살기위해노력할수는있겠다는다짐을줍니다.그리고더많이움켜쥐기위해애쓰기보다는내어줄때느끼는행복이크다는울림을줍니다.아직욕심이많은사람이지만나누며살겠노라다짐해봅니다.이태석신부님의헌신과숭고함에다시.한번고개를숙입니다.
# 10,고질라 VS. 콩,영화보니까고질라영화중에서역대급
# 10,고질라 VS. 콩,액션신최고사람은빠져
# 2,거룩한 계보,수준떨어지고역겨운영화
# -----------------------------------------------------
# 10,장사리 : 잊혀진 영웅들,
# 10,군도:민란의 시대,우리나라에서보기힘든영화
# 10,군도:민란의 시대,우리나라에서보기힘든영화
# 10,고질라 VS. 콩,역시고질라킹오브더몬스터
# 4,도굴,신선한과일로잼을만들어버림
# 2,호라이즌 라인,거너무한거아뇨?어거지로위기상황을만드는기막힌재주
# 1,천군,TaiwanNo.1
# 6,함정,이영화를본게함정이네요
# 10,맨 오브 스틸,모든걸다갖춘진정한남자의영화감동과슈퍼맨이악마가아닌천사로큰이유는아버지때문이다
# 5,미나리,한국을알리는데일조함
# -----------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
titleList = bs.select('p.goods_name.goods_icon > a > strong')
linklList = bs.select('p.goods_name.goods_icon > a')

for titleDom in titleList:
    title.append(titleDom.string)
for linkDom in linklList:
    link.append(linkDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml"
req.urlretrieve(url, savename)

xml = open(savename, "r", encoding="utf-8").read()
soup = BeautifulSoup(xml, 'html.parser')

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)]

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()):
        f.write(str(loc)+'\n')
        for name in info[loc]:
            f.write('\t'+str(name)+'\n')
# Out:
# {'서울': ['7~18', '7~18', '9~21', '9~21', '11~22', '11~22', '10~21', '10~21', '11~17', '11~17', '9~17', '8~16', '9~17'], '인천': ['7~15', '7~15', '9~17', '9~17', '10~20', '10~20', '10~18', '10~18', '9~16', '9~16', '9~15', '8~14', '8~15'], '수원': ['5~18', '5~18', '6~21', '6~21', '8~22', '8~22', '9~21', '9~21', '10~17', '10~17', '8~17', '7~16', '7~17'], '파주': ['2~18', '2~18', '2~20', '2~20', '5~22', '5~22', '6~21', '6~21', '9~16', '9~16', '6~16', '4~17', '5~18'], '이천': ['3~19', '3~19', '3~22', '3~22', '5~23', '5~23', '6~22', '6~22', '10~19', '10~19', '7~17', '5~16', '5~17'], '평택': ['4~18', '4~18', '4~20', '4~20', '7~22', '7~22', '8~22', '8~22', '11~18', '11~18', '8~16', '6~17', '6~19'], '춘천': ['2~19', '2~19', '3~21', '3~21', '5~23', '5~23', '6~22', '6~22', '10~19', '10~19', '8~18', '5~17', '5~18'], '원주': ['4~19', '4~19', '5~21', '5~21', '7~22', '7~22', '7~21', '7~21', '11~18', '11~18', '9~17', '6~16', '6~17'], '강릉': ['9~20', '9~20', '9~19', '9~19', '10~17', '10~17', '9~17', '9~17', '11~17', '11~17', '8~13', '7~13', '9~17'], '대전': ['5~19', '5~19', '5~22', '5~22', '8~22', '8~22', '9~23', '9~23', '12~19', '12~19', '9~17', '7~17', '7~18'], '세종': ['4~19', '4~19', '4~21', '4~21', '7~22', '7~22', '9~23', '9~23', '12~18', '12~18', '9~17', '6~17', '6~19'], '홍성': ['3~18', '3~18', '2~20', '2~20', '5~23', '5~23', '8~23', '8~23', '14~18', '14~18', '8~15', '5~16', '6~18'], '청주': ['5~19', '5~19', '6~22', '6~22', '9~22', '9~22', '10~22', '10~22', '11~18', '11~18', '10~17', '7~16', '7~18'], '충주': ['3~19', '3~19', '3~21', '3~21', '6~21', '6~21', '7~22', '7~22', '11~18', '11~18', '9~17', '5~16', '5~17'], '영동': ['3~19', '3~19', '2~22', '2~22', '5~21', '5~21', '8~23', '8~23', '12~19', '12~19', '8~17', '4~18', '4~19'], '광주': ['7~21', '7~21', '7~23', '7~23', '9~22', '9~22', '11~22', '11~22', '13~18', '13~18', '10~18', '8~18', '8~19'], '목포': ['7~17', '7~17', '7~19', '7~19', '9~20', '9~20', '11~19', '11~19', '13~17', '13~17', '9~14', '8~15', '8~15'], '여수': ['9~18', '9~18', '10~19', '10~19', '11~18', '11~18', '11~17', '11~17', '13~17', '13~17', '11~17', '10~16', '10~16'], '순천': ['7~21', '7~21', '7~22', '7~22', '9~21', '9~21', '11~20', '11~20', '14~18', '14~18', '11~19', '9~18', '9~20'], '광양': ['8~21', '8~21', '9~22', '9~22', '10~21', '10~21', '11~19', '11~19', '13~17', '13~17', '12~19', '9~17', '9~18'], '나주': ['4~20', '4~20', '4~22', '4~22', '6~22', '6~22', '10~22', '10~22', '14~19', '14~19', '9~18', '7~18', '7~20'], '전주': ['5~19', '5~19', '6~22', '6~22', '8~23', '8~23', '10~23', '10~23', '13~19', '13~19', '9~18', '7~17', '8~18'], '군산': ['5~18', '5~18', '5~20', '5~20', '7~22', '7~22', '9~22', '9~22', '13~18', '13~18', '9~16', '7~17', '7~17'], '정읍': ['4~18', '4~18', '5~21', '5~21', '7~22', '7~22', '8~22', '8~22', '13~18', '13~18', '9~17', '7~17', '7~18'], '남원': ['5~20', '5~20', '5~23', '5~23', '7~22', '7~22', '8~22', '8~22', '13~19', '13~19', '10~19', '6~18', '7~19'], '고창': ['4~18', '4~18', '4~20', '4~20', '6~21', '6~21', '9~21', '9~21', '14~19', '14~19', '9~15', '6~15', '6~16'], '무주': ['3~18', '3~18', '2~21', '2~21', '5~21', '5~21', '7~22', '7~22', '12~18', '12~18', '7~17', '4~17', '4~18'], '부산': ['11~19', '11~19', '10~19', '10~19', '11~18', '11~18', '12~18', '12~18', '14~18', '14~18', '13~17', '10~16', '9~18'], '울산': ['8~19', '8~19', '7~19', '7~19', '8~18', '8~18', '10~19', '10~19', '12~19', '12~19', '12~16', '8~15', '8~18'], '창원': ['8~20', '8~20', '7~20', '7~20', '8~20', '8~20', '10~19', '10~19', '12~18', '12~18', '12~18', '9~17', '8~18'], '진주': ['5~22', '5~22', '4~22', '4~22', '6~21', '6~21', '8~21', '8~21', '11~18', '11~18', '11~19', '7~18', '6~19'], '거창': ['3~21', '3~21', '3~22', '3~22', '5~20', '5~20', '5~20', '5~20', '10~18', '10~18', '10~18', '5~18', '5~19'], '통영': ['9~19', '9~19', '8~19', '8~19', '10~19', '10~19', '11~18', '11~18', '13~17', '13~17', '12~17', '9~17', '8~17'], '대구': ['8~21', '8~21', '7~22', '7~22', '8~21', '8~21', '10~21', '10~21', '12~19', '12~19', '11~18', '7~17', '8~19'], '안동': ['4~20', '4~20', '3~22', '3~22', '5~20', '5~20', '7~20' ...

# %%
import json
import urllib.request

#User-Agent를 조작하는 경우 
hdr = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '+ 
        'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.80 Safari/537.36'}

req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php', headers = hdr)
#req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php')
data = urllib.request.urlopen(req).read()
print(data)
#page = data.decode('utf-8', 'ignore')
res_content = json.loads(data)

print(res_content["result"])
